# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration

# %%
api_key = 'hf_foobarbaz'
path = 'ZhengjunHUO/distilbert-toxicity-classifier'

# %%
model = T5ForConditionalGeneration.from_pretrained("flan-t5-rl")
# Out:
# Some weights of the model checkpoint at flan-t5-rl were not used when initializing T5ForConditionalGeneration: ['v_head.summary.bias', 'v_head.summary.weight']
# - This IS expected if you are initializing T5ForConditionalGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing T5ForConditionalGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
rl_tokenizer = AutoTokenizer.from_pretrained("flan-t5-rl")

# %%
model.push_to_hub(
    repo_id=path, token=api_key
)
# Out:
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ZhengjunHUO/flan-t5-neutral-summarizer/commit/b3eca85d1a0caba37a6e76c4749cf45c82b418cc', commit_message='Upload T5ForConditionalGeneration', commit_description='', oid='b3eca85d1a0caba37a6e76c4749cf45c82b418cc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ZhengjunHUO/flan-t5-neutral-summarizer', endpoint='https://huggingface.co', repo_type='model', repo_id='ZhengjunHUO/flan-t5-neutral-summarizer'), pr_revision=None, pr_num=None)

# %%
rl_tokenizer.push_to_hub(
    repo_id=path, token=api_key
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ZhengjunHUO/flan-t5-neutral-summarizer/commit/faadfa2ae46a37656f1fccc8c5c6c63e0724bc08', commit_message='Upload tokenizer', commit_description='', oid='faadfa2ae46a37656f1fccc8c5c6c63e0724bc08', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ZhengjunHUO/flan-t5-neutral-summarizer', endpoint='https://huggingface.co', repo_type='model', repo_id='ZhengjunHUO/flan-t5-neutral-summarizer'), pr_revision=None, pr_num=None)
