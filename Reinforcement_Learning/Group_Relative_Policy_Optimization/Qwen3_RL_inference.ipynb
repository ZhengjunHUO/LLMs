# %%
from unsloth import FastLanguageModel
from vllm import SamplingParams
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 08-27 10:17:59 [__init__.py:241] Automatically detected platform cuda.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
max_seq_length = 2048
lora_rank = 32

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "ZhengjunHUO/Qwen3-4B-Reasoning",
    max_seq_length = max_seq_length,
    load_in_4bit = False,
    fast_inference = True,
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.7,
)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.8.9: Fast Qwen3 patching. Transformers: 4.55.2. vLLM: 0.10.1.
#    \\   /|    NVIDIA GeForce RTX 4070 Ti SUPER. Num GPUs = 1. Max memory: 15.577 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 8.9. CUDA Toolkit: 12.6. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading ZhengjunHUO/Qwen3-4B-Reasoning with actual GPU utilization = 66.74%
# Unsloth: Your GPU has CUDA compute capability 8.9 with VRAM = 15.58 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 160.
# Unsloth: vLLM's KV Cache can use up to 3.45 GB. Also swap space = 6 GB.
# Unsloth: Not an error, but `device` is not supported in vLLM. Skipping.
# INFO 08-27 10:18:34 [utils.py:326] non-default args: {'model': 'ZhengjunHUO/Qwen3-4B-Reasoning', 'dtype': torch.bfloat16, 'seed': 0, 'max_model_len': 2048, 'enable_prefix_caching': True, 'swap_space': 6, 'gpu_memory_utilization': 0.6674329306757673, 'max_num_batched_tokens': 2048, 'max_num_seqs': 160, 'max_logprobs': 0, 'disable_log_stats': True, 'enable_lora': True, 'max_lora_rank': 32, 'compilation_config': {"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":null,"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":16,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":null,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":null,"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":null,"local_cache_dir":null}}
# INFO 08-27 10:18:39 [__init__.py:711] Resolved architecture: Qwen3ForCausalLM
# INFO 08-27 10:18:39 [__init__.py:1750] Using max model len 2048
# INFO 08-27 10:18:40 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=2048.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/655 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/139 [00:00<?, ?B/s]
# INFO 08-27 10:18:45 [core.py:74] Initializing a V1 LLM engine (v0.10.1) with config: model='ZhengjunHUO/Qwen3-4B-Reasoning', speculative_config=None, tokenizer='ZhengjunHUO/Qwen3-4B-Reasoning', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=ZhengjunHUO/Qwen3-4B-Reasoning, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":16,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":320,"local_cache_dir":null}
# INFO 08-27 10:18:45 [parallel_state.py:1134] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# WARNING 08-27 10:18:45 [topk_topp_sampler.py:61] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 08-27 10:18:45 [gpu_model_runner.py:1953] Starting to load model ZhengjunHUO/Qwen3-4B-Reasoning...
# INFO 08-27 10:18:45 [gpu_model_runner.py:1985] Loading model from scratch...
# INFO 08-27 10:18:45 [cuda.py:328] Using Flash Attention backend on V1 engine.
# INFO 08-27 10:18:46 [weight_utils.py:296] Using model weights format ['*.safetensors']
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# INFO 08-27 10:22:17 [weight_utils.py:312] Time spent downloading weights for ZhengjunHUO/Qwen3-4B-Reasoning: 211.176989 seconds
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 08-27 10:22:19 [default_loader.py:262] Loading weights took 0.90 seconds
# INFO 08-27 10:22:19 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 08-27 10:22:19 [gpu_model_runner.py:2007] Model loading took 7.6334 GiB and 213.705130 seconds
# INFO 08-27 10:22:28 [backends.py:548] Using cache directory: /home/huo/.cache/vllm/torch_compile_cache/d29567f473/rank_0_0/backbone for vLLM's torch.compile
# INFO 08-27 10:22:28 [backends.py:559] Dynamo bytecode transform time: 8.05 s
# Unsloth: Compiling kernels: 100%|██████████| 7/7 [00:01<00:00,  5.25it/s, triton_poi_fused_view_6]
# INFO 08-27 10:22:32 [backends.py:194] Cache the graph for dynamic shape for later use
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 28.09it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 250.84it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 263.22it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 207.25it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 262.91it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 249.75it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 256.11it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 254.76it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 255.31it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 258.92it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 253.02it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 227.60it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 243.24it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 256.65it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 244.68it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 188.46it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 246.62it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 254.40it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 237.51it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 237.06it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 268.37it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 256.69it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 210.58it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 219.02it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 252.81it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 253.69it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 257.91it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 241.89it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 245.79it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 248.78it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 254.80it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 255.61it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 254.54it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 261.70it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 264.15it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 54.97it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# INFO 08-27 10:22:55 [backends.py:215] Compiling a graph for dynamic shape takes 26.89 s
# INFO 08-27 10:23:18 [monitor.py:34] torch.compile takes 34.93 s in total
# INFO 08-27 10:23:19 [gpu_worker.py:276] Available KV cache memory: 1.90 GiB
# INFO 08-27 10:23:19 [kv_cache_utils.py:849] GPU KV cache size: 13,840 tokens
# INFO 08-27 10:23:19 [kv_cache_utils.py:853] Maximum concurrency for 2,048 tokens per request: 6.76x
# INFO 08-27 10:23:19 [vllm_utils.py:643] Unsloth: Running patched vLLM v1 `capture_model`.
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 43/43 [00:09<00:00,  4.40it/s]
# INFO 08-27 10:23:29 [gpu_model_runner.py:2708] Graph capturing finished in 10 secs, took 0.55 GiB
# INFO 08-27 10:23:29 [vllm_utils.py:650] Unsloth: Patched vLLM v1 graph capture finished in 10 secs.
# INFO 08-27 10:23:29 [core.py:214] init engine (profile, create kv cache, warmup model) took 70.11 seconds
# INFO 08-27 10:23:31 [llm.py:298] Supported_tasks: ('generate',)
# Unsloth: Just some info: will skip parsing ['pre_feedforward_layernorm', 'post_feedforward_layernorm']
# Unsloth: Just some info: will skip parsing ['pre_feedforward_layernorm', 'post_feedforward_layernorm']

# %%
reasoning_start = "<start_breaking_down>"
reasoning_end   = "<end_breaking_down>"
solution_start  = "<SOLUTION>"
solution_end    = "</SOLUTION>"

system_prompt = \
f"""You are given a problem.
Think about the problem and provide your working out.
Place it between {reasoning_start} and {reasoning_end}.
Then, provide your solution between {solution_start}{solution_end}"""

chat_template = \
    "{% if messages[0]['role'] == 'system' %}"\
        "{{ messages[0]['content'] + eos_token }}"\
        "{% set loop_messages = messages[1:] %}"\
    "{% else %}"\
        "{{ '{system_prompt}' + eos_token }}"\
        "{% set loop_messages = messages %}"\
    "{% endif %}"\
    "{% for message in loop_messages %}"\
        "{% if message['role'] == 'user' %}"\
            "{{ message['content'] }}"\
        "{% elif message['role'] == 'assistant' %}"\
            "{{ message['content'] + eos_token }}"\
        "{% endif %}"\
    "{% endfor %}"\
    "{% if add_generation_prompt %}{{ '{reasoning_start}' }}"\
    "{% endif %}"

chat_template = chat_template\
    .replace("'{system_prompt}'",   f"'{system_prompt}'")\
    .replace("'{reasoning_start}'", f"'{reasoning_start}'")
tokenizer.chat_template = chat_template

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user",   "content": "What is the sqrt of 101?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    tokenize = False,
)

sampling_params = SamplingParams(
    temperature = 1.0,
    top_k = 50,
    max_tokens = 2048,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
output
# Out:
# "Okay, let's see. I need to find the square root of 101. Hmm, 101 isn't a perfect square, so the square root isn't an integer. But maybe I can estimate it?\n\nI know that 10 is 10 squared, which is 100. And 11 squared is 121. So 101 is between 100 and 121. That means the square root of 101 is between 10 and 11. Let me think of a number between 10 and 11 whose square is close to 101.\n\nLet me try 10.05. Wait, maybe that's a bit too low. Let me calculate 10.05 squared: (10 + 0.05)^2 = 100 + 2*10*0.05 + 0.05^2 = 100 + 1 + 0.0025 = 101.0025. Wow, that's almost exactly 101. So that's kind of close. But wait, 10.049 squared: (10 + 0.049)^2 = 100 + 2*10*0.049 + 0.049^2. Let's compute that. 2*10*0.049 is 0.98, and 0.049^2 is 0.002401. So total would be 100 + 0.98 + 0.002401 = 100.982401. That's less than 101. So 10.05 is a better guess. Wait, 10.05^2 is 101.0025, which is slightly over. So maybe the square root is around 10.0498 or something. But since 10.049^2 is 100.982401 and 10.05^2 is 101.0025, the square root must be between 10.049 and 10.05. But how precise do I need to be? The problem didn't specify, so maybe to two decimal places would be enough. So 10.05. Let me check again: 10.05 * 10.05. Let me compute that. 10*10=100, 10*0.05=0.5, 0.05*10=0.5, 0.05*0.05=0.0025. Add them up: 100 + 0.5 + 0.5 + 0.0025 = 101.0025. Yep, that's correct. So the square root of 101 is 10.05. \n\nWait, but maybe there's a better way. I can use the fact that 101 is 100 + 1, and the formula (a + b)^2 = a^2 + 2ab + b^2. So if a is 10, then b is 0.05, which we already used. Alternatively, maybe I can use long division for square roots, but that might be more complicated. Since the question didn't specify a method, my estimator works here. \n\nSo the square root of 101 is approximately 10.05. Let me confirm with a calculator. If I use a calculator, sqrt(101) is about 10.04987562112089, which confirms that 10.05 is a good approximation. \n\nTherefore, the square root of 101 is roughly 10.05. But since the problem likely expects an exact form, but since 101 is not a perfect square, the exact value is √101. But if we need a decimal approximation, then 10.05 should be sufficient. Since the options might not have exact values, we can round to two decimal places. So the answer is 10.05.\nTo find the square root of 101, we start by noting that 101 lies between the perfect squares 100 and 121. Therefore, the square root of 101 is between 10 and 11.\n\nWe can approximate more precisely by considering the square of numbers between 10 and 11. Let's try 10.05:\n\n\\[\n10.05^2 = (10 + 0.05)^2 = 10^2 + 2 \\cdot 10 \\cdot 0.05 + 0.05^2 = 100 + 1 + 0.0025 = 101.0025\n\\]\n\nThis value is very close to 101. To refine our approximation, we can check 10.049:\n\n\\[\n10.049^2 = (10 + 0.049)^2 = 10^2 + 2 \\cdot 10 \\cdot 0.049 + 0.049^2 = 100 + 0.98 + 0.002401 = 100.982401\n\\]\n\nSince \\(10.049^2 = 100.982401\\) is less than 101 and \\(10.05^2 = 101.0025\\) is slightly more than 101, the square root of 101 must lie between 10.049 and 10.05. For practical purposes, we can round to two decimal places, giving us:\n\n\\[\n\\boxed{10.05}\n\\]<end_breaking_down><SOLUTION>10.05</SOLUTION>"
