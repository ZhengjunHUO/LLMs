# %%
import os
from langchain_tavily import TavilySearch

# %%
if not os.environ.get("TAVILY_API_KEY"):
    print("Fail reading TAVILY_API_KEY from ENV")

# %%
# https://python.langchain.com/docs/integrations/tools/tavily_search
tool = TavilySearch(
    max_results=5,
    topic="general",
    # include_answer=False,
    # include_raw_content=False,
    # include_images=False,
    # include_image_descriptions=False,
    # search_depth="basic",
    # time_range="day",
    # include_domains=None,
    # exclude_domains=None
)

# %%
tool.invoke({"query": "What's GPT OSS ?"})
# Out:
# {'query': "What's GPT OSS ?",
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://medium.com/data-science-collective/what-you-need-to-know-about-gpt-oss-07b215f22d13',
#    'title': 'What you need to know about GPT-OSS',
#    'content': 'In the following sections, we will look at what “open” means in the context of GPT OSS, explore the architecture and training details, and outline practical ways you can start testing the models yourself. GPT OSS is OpenAI’s new family of open-weight large language models, released in two sizes: GPT OSS 120B and GPT OSS 20B. Large language models (LLMs) like GPT OSS are trained on massive amounts of text data to generate human-like responses to prompts. Compared to DeepSeek’s R1, which focuses on reinforcement learning for reasoning and often uses a fully dense architecture optimized for scratchpad-style thinking, GPT OSS brings reasoning ability through carefully scaled training, ultra-long context (up to 131K tokens), and specialized attention patterns.',
#    'score': 0.90849644,
#    'raw_content': None},
#   {'url': 'https://milvus.io/ai-quick-reference/what-is-gptoss-and-what-does-the-name-stand-for',
#    'title': 'What is GPT‑OSS, and what does the name stand for?',
#    'content': '* + What is Milvus GPT-OSS is OpenAI’s series of open-weight language models designed for powerful reasoning, agentic tasks, and versatile developer use cases. While the official documentation doesn’t explicitly define what “OSS” stands for, based on the context and OpenAI’s descriptions, it appears to refer to “Open Source Software” or similar terminology related to open-weight models. Unlike traditional closed-source models that only provide API access, GPT-OSS models give developers complete control over deployment, customization, and inference. The models feature configurable reasoning effort levels, full chain-of-thought access for debugging purposes, native agentic capabilities including function calling and web browsing, and support for fine-tuning to specific use cases. Zilliz Cloud is a managed vector database built on Milvus perfect for building GenAI applications.',
#    'score': 0.9067276,
#    'raw_content': None},
#   {'url': 'https://huggingface.co/blog/welcome-openai-gpt-oss',
#    'title': 'GPT OSS, the new open-source model family from OpenAI!',
#    'content': 'Image 20: Some benchmark results of OpenAI GPT OSS models The OpenAI GPT OSS models have been trained extensively to leverage tool use as part of their reasoning efforts. -d \'{"input": [{"role": "system", "content": "hello"}], "temperature": 1.0, "stream": true, "model": "openai/gpt-oss-120b"}\' -d \'{"messages": [{"role": "system", "content": "hello"}], "temperature": 1.0, "max_tokens": 1000, "stream": true, "model": "openai/gpt-oss-120b"}\' OpenAI GPT OSS is unusual because it distinguishes between a “system” message and a “developer” message at the start of the chat, but most other models only use “system”. In GPT OSS, the system message follows a strict format and contains information like the current date, the model identity and the level of reasoning effort to use, and the “developer” message is more freeform, which makes it (very confusingly) similar to the “system” messages of most other models.',
#    'score': 0.80698997,
#    'raw_content': None},
#   {'url': 'https://newsletter.languagemodels.co/p/the-illustrated-gpt-oss',
#    'title': 'The Illustrated GPT-OSS - by Jay Alammar',
#    'content': 'GPT-OSS is similar to previous models in that it’s an autoregressive Transformer generating one token at a time. For many more users, the details of the behavior and formatting of the model’s reasoning and tool calls are more important than the architecture. + **Input messages:** These builders get to set their own system and developer messages — defining general model expected behaviors and instructions, safety choices, reasoning level, and tool definitions for the model to use. + Power users who fine-tune models will have interact with all message types and format data in the right shape including for reasoning and tool calls and responses. So assuming we give the model a prompt where it needs to reason and use a couple of tool calls, the next figure shows a conversation where all three message types are used.',
#    'score': 0.7711725,
#    'raw_content': None},
#   {'url': 'https://www.reddit.com/r/LocalLLaMA/comments/1mjxx6j/gptoss_is_another_example_why_companies_must/',
#    'title': 'GPT-OSS is Another Example Why Companies Must Build ...',
#    'content': "Please, for the love of God, convince me that GPT-OSS is the best open-source model that exists today. There's no way the GPT-OSS 120B is better than Qwen-235B-A22B-2507, let alone DeepSeek R1. In about 2 weeks, Alibaba released a video model (Wan2.2) , an image model (Qwen-Image) that are the best open-source models in their categories, two amazing 30B models that are super fast and punch above their weight, and two incredible 4B models – yet barely any YouTubers covered them. When DeepSeek-R1 was released, real innovation became public – innovation GPT-OSS clearly built upon. Comparison of GPT-OSS and Qwen-235B-A22B-2507 Comparison of GPT-OSS and DeepSeek R1 *   Games  *   Other Games *   About Reddit",
#    'score': 0.71113056,
#    'raw_content': None}],
#  'response_time': 1.01,
#  'request_id': 'd36b6415-bed4-4575-a553-f6695ceb3a30'}

# %%
model_generated_tool_call = {
    "args": {"query": "MXFP4 quantization"},
    "id": "1",
    "name": "tavily",
    "type": "tool_call",
}
tool_msg = tool.invoke(model_generated_tool_call)

# %%
tool_msg
# Out:
# ToolMessage(content='{"query": "MXFP4 quantization", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://huggingface.co/blog/RakshitAralimatti/learn-ai-with-me", "title": "What\'s MXFP4? The 4-Bit Secret Powering OpenAI\'s GPT ...", "content": "2. Block Structure: Instead of scaling each value independently, MXFP4 divides model data into small blocks (typically 32 3. This structure lets MXFP4 efficiently represent the wide dynamic range found in modern AI models even with only 4 bits per value while keeping storage overhead low. These innovations enabled direct training of massive models in MXFP4 no more need to pre-train in high precision. ## MXFP4 in Action: OpenAI’s GPT‑OSS Models To prove that MXFP4 wasn’t just theory, OpenAI released the GPT‑OSS family, open-weight models trained natively with MXFP4: By packing more intelligence into fewer bits, and by making sure anyone can train and deploy powerful models, MXFP4 signals the democratization of AI is truly here.", "score": 0.98597, "raw_content": null}, {"url": "https://www.reddit.com/r/LocalLLaMA/comments/1mjtb8e/how_innovative_is_gpt_osss_4bit_quantization/", "title": "How innovative is GPT OSS\'s 4-bit quantization scheme ...", "content": "How innovative is GPT OSS\'s 4-bit quantization scheme (MXFP4), and can we expect DeepSeek MXFP4 models in the near future? Skip to main contentHow innovative is GPT OSS\'s 4-bit quantization scheme (MXFP4), and can we expect DeepSeek MXFP4 models in the near future? Open menu Open navigationGo to Reddit Home Image 2: r/LocalLLaMA iconr/LocalLLaMAImage 3: LlamaImage 4: Llama Subreddit to discuss AI & Llama, the large language model created by Meta AI. How innovative is GPT OSS\'s 4-bit quantization scheme (MXFP4), and can we expect DeepSeek MXFP4 models in the near future? How innovative is GPT OSS\'s 4-bit quantization scheme (MXFP4), and can we expect DeepSeek MXFP4 models in the near future? New to Reddit? Image 5: LlamaImage 6: Llama", "score": 0.98377, "raw_content": null}, {"url": "https://www.theregister.com/2025/08/10/openai_mxfp4/", "title": "OpenAI gpt-oss LLMs use MXFP4: smaller, faster, cheaper", "content": "Analysis Whether or not OpenAI\'s new open weights models are any good is still up for debate, but their use of a relatively new data type called MXFP4 is arguably more important, especially if it catches on among OpenAI\'s rivals. MXFP4 is a 4-bit floating point data type defined by the Open Compute Project (OCP), the hyperscaler cabal originally kicked off by Facebook in 2011 to try and make datacenter components cheaper and more readily available. Compared to a model trained at BF16 — the most common data type used for LLMs these days — MXFP4 would cut compute and memory requirements by roughly 75 percent.", "score": 0.9761, "raw_content": null}, {"url": "https://arxiv.org/pdf/2502.20853", "title": "Oscillation-Reduced MXFP4 Training for Vision Transformers", "content": "(2022) proposed methods that can be generalized to reduce oscillation in MXFP4 pre-training: The method “Dampen” tried to encourage latent weights to be closer to the quantized value to avoid fluctu-ating around the quantization boundary, by adding a regu-lation term Ldampen = ∥W − Q(W)∥2  During pre-training, we can test the rate of change for the master weight W, the quantized weight matrix Q(2) (W⊤)⊤, and activation Y at different stages. During pre-training, we can test the rate of change for the master weight W, the quantized weight matrix Q(2) (W⊤)⊤, and activation Y in different stages. A: When we use Q-EMA, there are two variables ( W & WEMA ) that determine the result of weight quantization, so training with Q-EMA results in a different MXFP4 training dynamic.", "score": 0.97587, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=1gcUQ-31Kdw", "title": "Albert Tseng - Training LLMs with MXFP4", "content": "In this talk I\'ll go over what low precision training is and then I\'ll talk about the ...
